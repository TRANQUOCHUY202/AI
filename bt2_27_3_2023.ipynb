# %% [markdown]
# <a href="https://colab.research.google.com/github/TRANQUOCHUY202/AI/blob/main/bt2_27_3_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10 
(x_train, y_train), (x_test ,y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 [==============================] - 6s 0us/step

# %%
Animal = x_train[150]
plt.imshow(Animal,cmap = plt.cm.binary)
plt.show
print("Hinh nay la: ", y_train[150])
# Out:
# Hinh nay la:  [3]

# %%
from keras.utils import load_img
from matplotlib import pyplot as plt

from tensorflow.keras.preprocessing.image import img_to_array
import numpy as np

filename = 'bird_small.jpg'
m=381
n=500

img = load_img(filename, target_size=(m, n))

plt.imshow(img)
plt.show()



img = img_to_array(img)
img = img.reshape(1, m, n, 3)
img = img.astype('float32')
img = img/255

predicted_class = np.argmax(model.predict(img), axis=-1)
print("Predicted class:", predicted_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-3a115acbd044> in <module>
#      21 img = img/255
#      22
# ---> 23 predicted_class = np.argmax(model.predict(img), axis=-1)
#      24 print("Predicted class:", predicted_class)
#
# NameError: name 'model' is not defined

# %%
from keras.datasets import cifar10
from keras.utils import to_categorical

# load the cifar10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# display an image from the dataset
plt.imshow(train_images[50])
plt.show()
print('This image is:', train_labels[50])

# preprocess the data
train_images = train_images.reshape((50000, 32 * 32 * 3))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 32 * 32 * 3))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# add a virtual layer to the input shape
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(512, input_shape=(32*32*3,), activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

# compile the model
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# train the model
model.fit(train_images, train_labels, epochs=10, batch_size=128)

# evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print('test accuracy:', test_acc)
print('test loss:', test_loss)
# Out:
# This image is: [9]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 512)               1573376
#
#  dense_1 (Dense)             (None, 10)                5130
#
# ...
# Total params: 1,578,506
# Trainable params: 1,578,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 391/391 [==============================] - 11s 27ms/step - loss: 2.1974 - accuracy: 0.2681
# Epoch 2/10
# 391/391 [==============================] - 11s 28ms/step - loss: 1.7937 - accuracy: 0.3586
# Epoch 3/10
# 391/391 [==============================] - 11s 29ms/step - loss: 1.7108 - accuracy: 0.3880
# Epoch 4/10
# 391/391 [==============================] - 11s 29ms/step - loss: 1.6574 - accuracy: 0.4118
# Epoch 5/10
# 391/391 [==============================] - 11s 29ms/step - loss: 1.6190 - accuracy: 0.4258
# Epoch 6/10
# ...

# %%
from keras.datasets import cifar10
from keras.utils import to_categorical

# load the cifar10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

for i in range(10):
    plt.subplot(3, 5, i+1)
    plt.tight_layout()
    plt.imshow(train_images[i], cmap = 'gray', interpolation = 'none')
    plt.title('So:{}'.format(train_labels[i]))
    plt.xticks([])
    plt.yticks([])
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
import numpy as np
from PIL import Image
import cv2 
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
from keras.utils import to_categorical

# load the cifar10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# tải hình ảnh và chuyển sang chế độ xám
image = Image.open("bird_small.jpg")
# thay dổi kích thước ảnh 
image = image.resize((32, 32))
# chuyển ảnh thành mảng 
image_array = np.array(image)
# làm phẳng mảng 
image_array = image_array.reshape((1, 32* 32*3))

image_array = image_array.astype('float32') / 255


i = np.uint8(image_array)
train_images[i]


plt.imshow(image, cmap = plt.cm.binary)
plt.show
print('ảnh này là: ', train_labels[i])
# Out:
# ảnh này là:  [[[6]
#   [6]
#   [6]
#   ...
#   [6]
#   [6]
#   [6]]]

# %%
import numpy as np
from PIL import Image
import cv2 
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
from keras.utils import to_categorical
from tensorflow import keras


from tensorflow import keras

# Load the pre-trained model from a file
model = keras.models.load_model('my_model.h5')

# load the cifar10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# tải hình ảnh và chuyển sang chế độ xám
image = Image.open("bird_small.jpg")
image = image.resize((32, 32))
image = np.array(image)
image_array = image.reshape((1, 32* 32*3))
# Normalize image array
image_array = image_array.astype('float32') / 255

# Predict the class of the image
prediction = model.predict(image_array)
predicted_class = np.argmax(prediction)

plt.imshow(image)
plt.show()
print('ảnh này được dự đoán là:', predicted_class)
print('ảnh này là:', train_labels[predicted_class][0])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-8079be9d30e6> in <module>
#      12
#      13 # Load the pre-trained model from a file
# ---> 14 model = keras.models.load_model('my_model.h5')
#      15
#      16 # load the cifar10 dataset
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     225                 if isinstance(filepath_str, str):
#     226                     if not tf.io.gfile.exists(filepath_str):
# ...
